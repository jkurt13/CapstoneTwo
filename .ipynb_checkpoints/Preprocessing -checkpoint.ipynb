# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from scipy.stats import t
from scipy.stats import norm
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.graphics.api import abline_plot 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing 
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn import tree, metrics
from io import StringIO  
from IPython.display import Image  
import pydotplus
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
drafted = pd.read_csv('drafted.csv')
undrafted = pd.read_csv('undrafted.csv')
draft_df = pd.read_csv('careers_df.csv')

# %%
drafted.head()
print(drafted.shape)
# Out:
# (517, 31)

# %%
undrafted.head()
print(undrafted.shape)
# Out:
# (275, 27)

# %%
draft_df.head()
print(draft_df.shape)
# Out:
# (792, 27)

# %%
draft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             792 non-null    float64
#  1   Name             792 non-null    object
#  2   College          791 non-null    object
#  3   POS              792 non-null    object
#  4   Height (in)      792 non-null    float64
#  5   Weight (lbs)     792 non-null    float64
#  6   40 Yard          649 non-null    float64
#  7   Bench Press      577 non-null    float64
#  8   Vert Leap (in)   581 non-null    float64
#  9   Broad Jump (in)  569 non-null    float64
#  10  Shuttle          483 non-null    float64
#  11  3Cone            474 non-null    float64
#  12  Win-Loss Record  703 non-null    object
#  13  Round            517 non-null    float64
#  14  Pick             517 non-null    float64
#  15  Team             517 non-null    object
#  16  Age              487 non-null    float64
#  17  To               482 non-null    float64
#  18  AP1              517 non-null    float64
#  19  PB               517 non-null    float64
#  20  St               517 non-null    float64
#  21  CarAV            482 non-null    float64
#  22  DrAV             446 non-null    float64
#  23  Solo             468 non-null    float64
#  24  Int              248 non-null    float64
#  25  Sacks            305 non-null    float64
#  26  Drafted          792 non-null    object
# dtypes: float64(21), object(6)
# memory usage: 167.2+ KB

# %%
draft_df['Broad Jump (in)'].replace(np.nan, np.mean(draft_df['Broad Jump (in)']), inplace=True)
draft_df['Bench Press'].replace(np.nan, np.mean(draft_df['Bench Press']), inplace=True)
draft_df['40 Yard'].replace(np.nan, np.mean(draft_df['40 Yard']), inplace=True)
draft_df['Vert Leap (in)'].replace(np.nan, np.mean(draft_df['Vert Leap (in)']), inplace=True)
draft_df['Shuttle'].replace(np.nan, np.mean(draft_df['Shuttle']), inplace=True)
draft_df['3Cone'].replace(np.nan, np.mean(draft_df['3Cone']), inplace=True)

# %%
drafted['PB_Select'] = 0
drafted.loc[drafted['PB'] > 0, 'PB_Select'] = 1
drafted.PB_Select
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 512    0
# 513    0
# 514    0
# 515    0
# 516    0
# Name: PB_Select, Length: 517, dtype: int64

# %%
drafted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             517 non-null    float64
#  1   Name             517 non-null    object
#  2   College          516 non-null    object
#  3   POS              517 non-null    object
#  4   Height (in)      517 non-null    float64
#  5   Weight (lbs)     517 non-null    float64
#  6   40 Yard          517 non-null    float64
#  7   Bench Press      517 non-null    float64
#  8   Vert Leap (in)   517 non-null    float64
#  9   Broad Jump (in)  517 non-null    float64
#  10  Shuttle          517 non-null    float64
#  11  3Cone            517 non-null    float64
#  12  Win-Loss Record  457 non-null    object
#  13  Round            517 non-null    float64
#  14  Pick             517 non-null    float64
#  15  Team             517 non-null    object
#  16  Age              487 non-null    float64
#  17  To               517 non-null    float64
#  18  AP1              517 non-null    float64
#  19  PB               517 non-null    float64
#  20  St               517 non-null    float64
#  21  CarAV            482 non-null    float64
#  22  DrAV             446 non-null    float64
#  23  Solo             517 non-null    float64
#  24  Int              517 non-null    float64
#  25  Sacks            517 non-null    float64
#  26  Drafted          517 non-null    object
#  27  Solos_Per_Year   517 non-null    float64
#  28  Ints_Per_Year    517 non-null    float64
#  29  Sacks_Per_Year   517 non-null    float64
#  30  Solos_Per_Game   517 non-null    float64
#  31  PB_Select        517 non-null    int64
# dtypes: float64(25), int64(1), object(6)
# memory usage: 129.4+ KB

# %%
draft_df['Drafted'] = draft_df.Drafted.replace(['D', 'U'], [1, 0])
draft_df.Drafted.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

y = (drafted.PB_Select == 0).values
X = drafted[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone', 'Int', 'Sacks', 'Solos_Per_Year']].values
# Split the data into a training and test set.
Xlr, Xtestlr, ylr, ytestlr = train_test_split(X, y, test_size=0.30, random_state=123)

X_scaled = preprocessing.scale(Xlr)

clf = LogisticRegression()
# Fit the model on the trainng data.
clf.fit(X_scaled, ylr)
# Print the accuracy from the testing data.
print(accuracy_score(clf.predict(Xtestlr), ytestlr))
# Out:
# 0.10256410256410256

# %%
logreg = LogisticRegression()
logreg.fit(X_scaled, ylr)
y_pred = logreg.predict(Xtestlr)

print(confusion_matrix(ytestlr, y_pred))
print(classification_report(ytestlr, y_pred))
# Out:
# [[ 16   0]
#  [140   0]]
#               precision    recall  f1-score   support
#
#        False       0.10      1.00      0.19        16
#         True       0.00      0.00      0.00       140
#
#     accuracy                           0.10       156
#    macro avg       0.05      0.50      0.09       156
# weighted avg       0.01      0.10      0.02       156
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

def cv_score(clf, x, y, score_func=accuracy_score):
    result = 0
    nfold = 5
    for train, test in KFold(nfold).split(x): # split data into train/test groups, 5 times
        clf.fit(x[train], y[train]) # fit
        result += score_func(clf.predict(x[test]), y[test]) # evaluate score function on held-out data
    return result / nfold # average

# %%
clf = LogisticRegression()
score = cv_score(clf, X_scaled, ylr)
print(score)
# Out:
# 0.9195966514459665

# %%
# your turn
from sklearn.model_selection import GridSearchCV

params = {'C': [0.001, 0.1, 1, 10, 100]}
clfl3 = LogisticRegression()
clf_fit = GridSearchCV(clfl3, param_grid=params, cv=5, scoring='accuracy')
clf_fit.fit(X_scaled, ylr)

clf_fit.best_estimator_, clf_fit.best_params_, clf_fit.best_score_
# Out:
# (LogisticRegression(C=1), {'C': 1}, 0.9196727549467276)

# %%
clfl4=LogisticRegression(C=clf_fit.best_params_['C'])
clfl4.fit(X_scaled, ylr)
ylrpred1 = clfl4.predict(Xtestlr)
accuracy_score(ylrpred1, ytestlr)
# Out:
# 0.10256410256410256

# %%
logreg = LogisticRegression()
logreg.fit(X_scaled, ylr)
y_pred = logreg.predict(Xtestlr)

print(confusion_matrix(ytestlr, y_pred))
print(classification_report(ytestlr, y_pred))
# Out:
# [[ 16   0]
#  [140   0]]
#               precision    recall  f1-score   support
#
#        False       0.10      1.00      0.19        16
#         True       0.00      0.00      0.00       140
#
#     accuracy                           0.10       156
#    macro avg       0.05      0.50      0.09       156
# weighted avg       0.01      0.10      0.02       156
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Logistic Regression with PCA

# %%
pca = PCA()
log = LogisticRegression()
pipe = Pipeline(steps=[('pca', pca), ('logistic', log)])

# %%
y = (drafted.PB_Select == 0).values
X = drafted[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone', 'Int', 'Sacks', 'Solos_Per_Year']].values
# Split the data into a training and test set.
Xlr, Xtestlr, ylr, ytestlr = train_test_split(X, y, test_size=0.30, random_state=123)

X_scaled = preprocessing.scale(Xlr)

param_grid = {'pca__n_components': [2, 5, 8, 10],
             'logistic__C': [0.001, 0.01, 0.1, 0.5, 1]}

search = GridSearchCV(pipe, param_grid)
search.fit(X_scaled, ylr)

print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.922):
# {'logistic__C': 0.5, 'pca__n_components': 10}

# %%
pca.fit(X_scaled)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(np.arange(1, pca.n_components_ + 1),
         pca.explained_variance_ratio_, '+', linewidth=2)
ax0.set_ylabel('PCA explained variance ratio')

ax0.axvline(search.best_estimator_.named_steps['pca'].n_components,
            linestyle=':', label='n_components chosen')
ax0.legend(prop=dict(size=12))

# For each number of components, find the best classifier results
results = pd.DataFrame(search.cv_results_)
components_col = 'param_pca__n_components'
best_clfs = results.groupby(components_col).apply(
    lambda g: g.nlargest(1, 'mean_test_score'))

best_clfs.plot(x=components_col, y='mean_test_score', yerr='std_test_score',
               legend=False, ax=ax1)
ax1.set_ylabel('Classification accuracy (val)')
ax1.set_xlabel('n_components')

plt.xlim(-1, 15)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Desicion Tree

# %%
draft_df.columns
# Out:
# Index(['Year', 'Name', 'College', 'POS', 'Height (in)', 'Weight (lbs)',
#        '40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)',
#        'Shuttle', '3Cone', 'Win-Loss Record', 'Round', 'Pick', 'Team', 'Age',
#        'To', 'AP1', 'PB', 'St', 'CarAV', 'DrAV', 'Solo', 'Int', 'Sacks',
#        'Drafted'],
#       dtype='object')

# %%
y = drafted.PB_Select
X = drafted[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
draft_dt2 = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3)

draft_dt2.fit(X_train, y_train)

y_pred = draft_dt2.predict(X_test)

y_pred = pd.Series(y_pred)

draft_dt2
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
# Now we want to visualize the tree
dot_data = StringIO()

# We can do so with export_graphviz
tree.export_graphviz(draft_dt2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=X_train.columns,class_names = ["unselected", "Selected"]) 

# Alternatively for class_names use entr_model.classes_
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
# Run this block for model evaluation
print("Model Entropy max_depth = 3")
print("Accuracy:", metrics.accuracy_score(y_test,y_pred))
print("Balanced accuracy:", metrics.balanced_accuracy_score(y_test,y_pred))
print('Precision score' , metrics.precision_score(y_test,y_pred, pos_label = 1))
print('Recall score' , metrics.recall_score(y_test,y_pred, pos_label = 0))
# Out:
# Model Entropy max_depth = 3
# Accuracy: 0.8846153846153846
# Balanced accuracy: 0.5
# Precision score 0.0
# Recall score 1.0
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
draft_gini2 = tree.DecisionTreeClassifier(criterion='gini', max_depth=3)

draft_gini2.fit(X_train, y_train)

y_pred = draft_gini2.predict(X_test)

y_pred = pd.Series(y_pred)

draft_gini2
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# Now we want to visualize the tree
dot_data = StringIO()

# We can do so with export_graphviz
tree.export_graphviz(draft_gini2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=X_train.columns,class_names = ["unselected", "Selected"]) 

# Alternatively for class_names use entr_model.classes_
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
# Run this block for model evaluation
print("Model Entropy max_depth = 3")
print("Accuracy:", metrics.accuracy_score(y_test,y_pred))
print("Balanced accuracy:", metrics.balanced_accuracy_score(y_test,y_pred))
print('Precision score' , metrics.precision_score(y_test,y_pred, pos_label = 1))
print('Recall score' , metrics.recall_score(y_test,y_pred, pos_label = 0))
# Out:
# Model Entropy max_depth = 3
# Accuracy: 0.8846153846153846
# Balanced accuracy: 0.5
# Precision score 0.0
# Recall score 1.0
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Random Forest

# %%
draft_rf1 = RandomForestClassifier(max_depth=5, random_state=123)

draft_rf1.fit(X_train, y_train)

y_pred = draft_rf1.predict(X_test)

y_pred = pd.Series(y_pred)

draft_rf1
# Out:
# RandomForestClassifier(max_depth=5, random_state=123)

# %%
print("Random Forest Model - max depth 3")
print("Accuracy:", metrics.accuracy_score(y_test,y_pred))
print("Balanced accuracy:", metrics.balanced_accuracy_score(y_test,y_pred))
print('Precision score' , metrics.precision_score(y_test,y_pred, pos_label = 1))
print('Recall score' , metrics.recall_score(y_test,y_pred, pos_label = 0))
# Out:
# Random Forest Model - max depth 3
# Accuracy: 0.8846153846153846
# Balanced accuracy: 0.5
# Precision score 0.0
# Recall score 1.0
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_regression

# %%
RF_pipe = make_pipeline(
    preprocessing.StandardScaler(),
    RandomForestRegressor(random_state=123))

# %%
rf_default_cv_results = cross_validate(RF_pipe, X_train, y_train, cv=5)
rf_default_cv_results
# Out:
# {'fit_time': array([0.25531483, 0.22535777, 0.21542382, 0.23337531, 0.23537064]),
#  'score_time': array([0.00997353, 0.00897598, 0.01097035, 0.01097059, 0.014961  ]),
#  'test_score': array([-1.167776  , -0.00689643, -0.24521465, -0.15473286, -0.11543119])}

# %%
rf_cv_scores = rf_default_cv_results['test_score']
rf_cv_scores
# Out:
# array([-1.167776  , -0.00689643, -0.24521465, -0.15473286, -0.11543119])

# %%
np.mean(rf_cv_scores), np.std(rf_cv_scores)
# Out:
# (-0.3380102262766963, 0.42187453693681887)

# %%
n_est = [int(n) for n in np.logspace(start=1, stop=3, num=20)]
grid_params = {
        'randomforestregressor__n_estimators': n_est,
        'standardscaler': [preprocessing.StandardScaler(), None]
}
grid_params
# Out:
# {'randomforestregressor__n_estimators': [10,
#   12,
#   16,
#   20,
#   26,
#   33,
#   42,
#   54,
#   69,
#   88,
#   112,
#   143,
#   183,
#   233,
#   297,
#   379,
#   483,
#   615,
#   784,
#   1000],
#  'standardscaler': [StandardScaler(), None]}

# %%
rf_grid_cv = GridSearchCV(RF_pipe, param_grid=grid_params, cv=5, n_jobs=-1)

# %%
rf_grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('randomforestregressor',
#                                         RandomForestRegressor(random_state=123))]),
#              n_jobs=-1,
#              param_grid={'randomforestregressor__n_estimators': [10, 12, 16, 20,
#                                                                  26, 33, 42, 54,
#                                                                  69, 88, 112,
#                                                                  143, 183, 233,
#                                                                  297, 379, 483,
#                                                                  615, 784,
#                                                                  1000],
#                          'standardscaler': [StandardScaler(), None]})

# %%
rf_grid_cv.best_params_
# Out:
# {'randomforestregressor__n_estimators': 69, 'standardscaler': StandardScaler()}

# %%
rf_best_cv_results = cross_validate(rf_grid_cv.best_estimator_, Xlr, ylr, cv=5)
rf_best_scores = rf_best_cv_results['test_score']
rf_best_scores
# Out:
# array([0.02113793, 0.48424867, 0.52349912, 0.36090584, 0.44777121])

# %%
np.mean(rf_best_scores), np.std(rf_best_scores)
# Out:
# (0.3675125547138135, 0.181339246107352)

# %%
plt.subplots(figsize=(10, 5))
imps = rf_grid_cv.best_estimator_.named_steps.randomforestregressor.feature_importances_
rf_feat_imps = pd.Series(imps, index=X_train.columns).sort_values(ascending=False)
rf_feat_imps.plot(kind='bar')
plt.xlabel('features')
plt.ylabel('importance')
plt.title('Best random forest regressor feature importances');

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn import preprocessing
from sklearn.ensemble import GradientBoostingClassifier

# %%
drafted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             517 non-null    float64
#  1   Name             517 non-null    object
#  2   College          516 non-null    object
#  3   POS              517 non-null    object
#  4   Height (in)      517 non-null    float64
#  5   Weight (lbs)     517 non-null    float64
#  6   40 Yard          517 non-null    float64
#  7   Bench Press      517 non-null    float64
#  8   Vert Leap (in)   517 non-null    float64
#  9   Broad Jump (in)  517 non-null    float64
#  10  Shuttle          517 non-null    float64
#  11  3Cone            517 non-null    float64
#  12  Win-Loss Record  457 non-null    object
#  13  Round            517 non-null    float64
#  14  Pick             517 non-null    float64
#  15  Team             517 non-null    object
#  16  Age              487 non-null    float64
#  17  To               517 non-null    float64
#  18  AP1              517 non-null    float64
#  19  PB               517 non-null    float64
#  20  St               517 non-null    float64
#  21  CarAV            482 non-null    float64
#  22  DrAV             446 non-null    float64
#  23  Solo             517 non-null    float64
#  24  Int              517 non-null    float64
#  25  Sacks            517 non-null    float64
#  26  Drafted          517 non-null    object
#  27  Solos_Per_Year   517 non-null    float64
#  28  Ints_Per_Year    517 non-null    float64
#  29  Sacks_Per_Year   517 non-null    float64
#  30  Solos_Per_Game   517 non-null    float64
#  31  PB_Select        517 non-null    int64
# dtypes: float64(25), int64(1), object(6)
# memory usage: 129.4+ KB

# %%
drafted_num = drafted.select_dtypes(include=['float64'])
drafted_num.shape
# Out:
# (517, 25)

# %%
y = drafted[['PB_Select']]
X = drafted[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone', 'Solos_Per_Year']]
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=0.75, test_size=0.25)

# %%
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(n_estimators=10, learning_rate = learning_rate, max_features=2, max_depth = 2, random_state = 0)
    gb.fit(X_train, y_train)
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_train, y_train)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_test, y_test)))
    print()
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.886
# Accuracy score (validation): 0.885
#
# Learning rate:  0.1
# Accuracy score (training): 0.886
# Accuracy score (validation): 0.885
#
# Learning rate:  0.25
# Accuracy score (training): 0.910
# Accuracy score (validation): 0.885
#
# Learning rate:  0.5
# Accuracy score (training): 0.941
# Accuracy score (validation): 0.900
#
# Learning rate:  0.75
# Accuracy score (training): 0.941
# Accuracy score (validation): 0.877
#
# Learning rate:  1
# Accuracy score (training): 0.943
# Accuracy score (validation): 0.885
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
from sklearn.metrics import accuracy_score

gbc = GradientBoostingClassifier(n_estimators=20, learning_rate = 1, max_features=2, max_depth = 2, random_state = 0)
gbc.fit(X_train, y_train)
y_pred = gbc.predict(X_test)
score = accuracy_score(y_test, y_pred)
print(score)

cm = confusion_matrix(y_test, y_pred)
print(cm)

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
# 0.8769230769230769
# [[108   7]
#  [  9   6]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       115
#            1       0.46      0.40      0.43        15
#
#     accuracy                           0.88       130
#    macro avg       0.69      0.67      0.68       130
# weighted avg       0.87      0.88      0.87       130
# C:\Users\vtkurt13\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# plot the roc curve for the model
plt.plot(fpr, tpr, linestyle='--')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the plot
plt.show()

# %% [markdown]
# # Gradient Boosting with PCA

# %%
pca = PCA()
gb = GradientBoostingClassifier(n_estimators=20, max_features=2, max_depth = 2, random_state = 0)

pipe = Pipeline(steps=[('pca', pca), ('gradient', gb)])

# %%
y = (drafted.PB_Select == 0).values
X = drafted[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone', 'Int', 'Sacks', 'Solos_Per_Year']].values
# Split the data into a training and test set.
Xlr, Xtestlr, ylr, ytestlr = train_test_split(X, y, test_size=0.30, random_state=123)

X_scaled = preprocessing.scale(Xlr)

param_grid = {'pca__n_components': [2, 5, 8, 10],
             'gradient__learning_rate': [0.05, 0.1, 0.25, 0.5, 0.75, 1]
}

search = GridSearchCV(pipe, param_grid)
search.fit(X_scaled, ylr)

print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.925):
# {'gradient__learning_rate': 0.5, 'pca__n_components': 8}

# %%
pca.fit(X_scaled)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(np.arange(1, pca.n_components_ + 1),
         pca.explained_variance_ratio_, '+', linewidth=2)
ax0.set_ylabel('PCA explained variance ratio')

ax0.axvline(search.best_estimator_.named_steps['pca'].n_components,
            linestyle=':', label='n_components chosen')
ax0.legend(prop=dict(size=12))

# For each number of components, find the best classifier results
results = pd.DataFrame(search.cv_results_)
components_col = 'param_pca__n_components'
best_clfs = results.groupby(components_col).apply(
    lambda g: g.nlargest(1, 'mean_test_score'))

best_clfs.plot(x=components_col, y='mean_test_score', yerr='std_test_score',
               legend=False, ax=ax1)
ax1.set_ylabel('Classification accuracy (val)')
ax1.set_xlabel('n_components')

plt.xlim(-1, 15)

plt.tight_layout()
plt.show()

# %%
# Import Lasso
from sklearn.linear_model import Lasso


y = draft_df['Drafted']
X = draft_df[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone']]
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)
X_scaled = pd.DataFrame(X_scaled)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=0.75, test_size=0.25)

# Instantiate a lasso regressor: lasso
lasso = Lasso(alpha=0.4, normalize=True)

# Fit the regressor to the data
lasso.fit(X_scaled, y)

# Compute and print the coefficients
lasso_coef = lasso.fit(X_scaled, y).coef_
print(lasso_coef)
drafted_columns = X.columns
#Plot the coefficients
plt.plot(range(len(drafted_columns)), lasso_coef)
plt.xticks(range(len(drafted_columns)), drafted_columns.values, rotation=60)
plt.margins(0.02)
plt.show()
# Out:
# [ 0.  0. -0.  0.  0.  0. -0. -0.]

# %% [markdown]
# # Unsupervised Learning

# %%
unlabeled_draft = draft_df.drop('Drafted', axis=1)
unlabeled_draft = unlabeled_draft.select_dtypes(include=['float64'])
unlabeled_draft = unlabeled_draft.dropna(axis=1)
unlabeled_draft = unlabeled_draft.drop('Year', axis=1)
scaler = preprocessing.StandardScaler().fit(unlabeled_draft)
unlabeled_scaled = scaler.transform(unlabeled_draft)
unlabeled_scaled = pd.DataFrame(unlabeled_scaled)
unlabeled_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       792 non-null    float64
#  1   1       792 non-null    float64
#  2   2       792 non-null    float64
#  3   3       792 non-null    float64
#  4   4       792 non-null    float64
#  5   5       792 non-null    float64
#  6   6       792 non-null    float64
#  7   7       792 non-null    float64
# dtypes: float64(8)
# memory usage: 49.6 KB

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(unlabeled_scaled)
print(pca.explained_variance_)
print(pca.components_)
# Out:
# [4.58488387 1.14683925]
# [[ 0.28447934  0.39855331  0.41197645  0.26449816 -0.35317874 -0.37487804
#    0.34866203  0.3656623 ]
#  [-0.54153376 -0.36273963 -0.01618183 -0.46369117 -0.33901588 -0.26108991
#    0.33005471  0.26048795]]

# %%
plt.plot(unlabeled_scaled.iloc[:, 0], unlabeled_scaled.iloc[:, 1], 'og', alpha=0.3)
plt.axis('equal')
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    plt.plot([0, v[0]], [0, v[1]], '-k', lw=3)

# %%
clf = PCA(0.95)
unlabeled_trans = clf.fit_transform(unlabeled_scaled)
print(unlabeled_scaled.shape)
print(unlabeled_trans.shape)
# Out:
# (792, 8)
# (792, 6)

# %%
unlabeled_new = clf.inverse_transform(unlabeled_trans)
plt.plot(unlabeled_scaled.iloc[:, 0], unlabeled_scaled.iloc[:, 1], 'og', alpha=0.2)
plt.plot(unlabeled_new[:, 0], unlabeled_new[:, 1], 'og', alpha=0.8)
plt.axis('equal');

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans
est = KMeans(3)
est.fit(unlabeled_scaled)
y_means = est.predict(unlabeled_scaled)
plt.scatter(unlabeled_scaled.iloc[:,3], unlabeled_scaled.iloc[:, 4], c=y_means, s=50)

# %%
drafted_unlabeled = drafted.drop(['PB', 'PB_Select'], axis=1)
drafted_unlabeled = drafted_unlabeled.dropna(axis=1)
drafted_unlabeled = drafted_unlabeled.drop('Year', axis=1)
drafted_unlabeled = drafted_unlabeled.select_dtypes(include=['float64'])
drafted_unlabeled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Height (in)      517 non-null    float64
#  1   Weight (lbs)     517 non-null    float64
#  2   40 Yard          517 non-null    float64
#  3   Bench Press      517 non-null    float64
#  4   Vert Leap (in)   517 non-null    float64
#  5   Broad Jump (in)  517 non-null    float64
#  6   Shuttle          517 non-null    float64
#  7   3Cone            517 non-null    float64
#  8   Round            517 non-null    float64
#  9   Pick             517 non-null    float64
#  10  To               517 non-null    float64
#  11  AP1              517 non-null    float64
#  12  St               517 non-null    float64
#  13  Solo             517 non-null    float64
#  14  Int              517 non-null    float64
#  15  Sacks            517 non-null    float64
#  16  Solos_Per_Year   517 non-null    float64
#  17  Ints_Per_Year    517 non-null    float64
#  18  Sacks_Per_Year   517 non-null    float64
#  19  Solos_Per_Game   517 non-null    float64
# dtypes: float64(20)
# memory usage: 80.9 KB

# %%
scaler = preprocessing.StandardScaler().fit(drafted_unlabeled)
drafted_scaled = scaler.transform(drafted_unlabeled)
drafted_scaled = pd.DataFrame(drafted_scaled)

# %%
import matplotlib.colors

model = KMeans(n_clusters = 2)
cluster_assignments = model.fit_predict(drafted_scaled)

cmap = matplotlib.colors.ListedColormap(['red', 'green', 'blue'])

pca = PCA(n_components=2)
pc1, pc2 = zip(*pca.fit_transform(drafted_scaled))
plt.scatter(pc1, pc2, c=cluster_assignments.tolist(), cmap = cmap)

# %%
pca = PCA()
pca.fit(drafted_scaled)

variance = pca.explained_variance_ratio_

plt.plot(range(len(variance)), variance)

plt.xlabel('NUmber of Components')
plt.ylabel('Proportion of variance Explained')
# Out:
# Text(0, 0.5, 'Proportion of variance Explained')

# %%
from sklearn.cluster import AgglomerativeClustering

pca = PCA(n_components=2)
X_principle = pca.fit_transform(drafted_scaled)
X_principle = pd.DataFrame(X_principle)
X_principle.columns=['P1', 'P2']

# %%
agglo = AgglomerativeClustering(n_clusters=2)
agg = agglo.fit_predict(X_principle)

plt.figure(figsize=(6,6))
plt.scatter(X_principle['P1'], X_principle['P2'], c = agg, cmap='rainbow')

# %%
#height_weight = draft_df[['Height (in)', 'Weight (lbs)']]
height_weight = draft_df[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone']]

height_weight.info()
print(draft_df.POS.unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Height (in)      792 non-null    float64
#  1   Weight (lbs)     792 non-null    float64
#  2   40 Yard          792 non-null    float64
#  3   Bench Press      792 non-null    float64
#  4   Vert Leap (in)   792 non-null    float64
#  5   Broad Jump (in)  792 non-null    float64
#  6   Shuttle          792 non-null    float64
#  7   3Cone            792 non-null    float64
# dtypes: float64(8)
# memory usage: 49.6 KB
# ['DE' 'CB' 'DT' 'FS' 'OLB' 'SS' 'ILB']

# %%
scaler = preprocessing.StandardScaler().fit(height_weight)
hw_scaled = scaler.transform(height_weight)

# %%
krange = list(range(2, 11))

ss = []

assignments = {}

for k in krange:
    kmeans = KMeans(n_clusters=k)
    k_predict = kmeans.fit_predict(hw_scaled)
    centroid = kmeans.cluster_centers_
    ss.append(np.sum((hw_scaled - centroid[k_predict]) ** 2))
    assignments[str(k)] = k_predict
    
_ = plt.plot(krange, ss)
_ = plt.xlabel("$K$")
_ = plt.ylabel("Sum of Squares")

# %%
kmeans = KMeans(n_clusters = 3)
k_predict = kmeans.fit_predict(height_weight)
plt.scatter(height_weight.iloc[:, 0], height_weight.iloc[:, 1], c=k_predict, s=50)

# %%
pos = draft_df.POS
pos
# Out:
# 0       DE
# 1       CB
# 2       DE
# 3       CB
# 4       DT
#       ...
# 787     CB
# 788     SS
# 789    OLB
# 790     SS
# 791     CB
# Name: POS, Length: 792, dtype: object

# %%
df = pd.DataFrame({'labels': k_predict, 'POS': pos})

print(df.sort_values(by='labels'))
# Out:
#      labels  POS
# 0         0   DE
# 583       0  ILB
# 584       0   SS
# 284       0   DE
# 283       0  ILB
# ..      ...  ...
# 174       2   DT
# 171       2   DE
# 664       2   DE
# 193       2   DE
# 455       2   DT
#
# [792 rows x 2 columns]

# %%
df.sort_values(by='labels').value_counts()
# Out:
# labels  POS
# 1       CB     163
# 0       OLB    131
# 2       DT     124
# 0       DE     109
# 1       FS      86
# 0       ILB     70
# 1       SS      49
# 2       DE      42
# 0       SS      13
#         FS       3
# 1       OLB      2
# dtype: int64

# %%
X = drafted[['Height (in)', 'Weight (lbs)','40 Yard', 'Bench Press', 'Vert Leap (in)', 'Broad Jump (in)', 'Shuttle', '3Cone']]

scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %%
krange = list(range(2, 11))

ss = []

assignments = {}

for k in krange:
    kmeans = KMeans(n_clusters=k)
    k_predict = kmeans.fit_predict(X_scaled)
    centroid = kmeans.cluster_centers_
    ss.append(np.sum((X_scaled - centroid[k_predict]) ** 2))
    assignments[str(k)] = k_predict
    
_ = plt.plot(krange, ss)
_ = plt.xlabel("$K$")
_ = plt.ylabel("Sum of Squares")

# %%
kmeans = KMeans(n_clusters = 3)
k_predict = kmeans.fit_predict(X)
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=k_predict, s=50)

# %%
select = drafted.PB_Select

# %%
df = pd.DataFrame({'labels': k_predict, 'Selected': select})
df.sort_values(by='labels').value_counts()
# Out:
# labels  Selected
# 0       0           187
# 1       0           178
# 2       0            93
# 1       1            26
# 0       1            25
# 2       1             8
# dtype: int64
